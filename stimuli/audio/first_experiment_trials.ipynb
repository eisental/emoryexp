# %%
from pathlib import Path
from tqdm.auto import tqdm
import pandas as pd

# %%
audio_dir = Path(".")

# %%
coded_exp1_trials = [p.stem.split('_') for p in sorted(audio_dir.glob('*.mp3'))]

# %%
columns = ['Medium', 'Language', 'Subject', 'Unit', 'Non_word', 'Picture set', 'Picture orientation', 'Meaning']

# %%
coded_exp1_trials
# Out:
# [['Mu', 'H', '0', 'Ml', 'B', '1', 'L', '1'],
#  ['Mu', 'H', '0', 'Ml', 'B', '1', 'L', '10'],
#  ['Mu', 'H', '0', 'Ml', 'B', '1', 'L', '11'],
#  ['Mu', 'H', '0', 'Ml', 'B', '1', 'L', '12'],
#  ['Mu', 'H', '0', 'Ml', 'B', '1', 'L', '2'],
#  ['Mu', 'H', '0', 'Ml', 'B', '1', 'L', '3'],
#  ['Mu', 'H', '0', 'Ml', 'B', '1', 'L', '4'],
#  ['Mu', 'H', '0', 'Ml', 'B', '1', 'L', '5'],
#  ['Mu', 'H', '0', 'Ml', 'B', '1', 'L', '6'],
#  ['Mu', 'H', '0', 'Ml', 'B', '1', 'L', '7'],
#  ['Mu', 'H', '0', 'Ml', 'B', '1', 'L', '8'],
#  ['Mu', 'H', '0', 'Ml', 'B', '1', 'L', '9'],
#  ['Mu', 'H', '0', 'Ml', 'B', '2', 'R', '1'],
#  ['Mu', 'H', '0', 'Ml', 'B', '2', 'R', '10'],
#  ['Mu', 'H', '0', 'Ml', 'B', '2', 'R', '11'],
#  ['Mu', 'H', '0', 'Ml', 'B', '2', 'R', '12'],
#  ['Mu', 'H', '0', 'Ml', 'B', '2', 'R', '2'],
#  ['Mu', 'H', '0', 'Ml', 'B', '2', 'R', '3'],
#  ['Mu', 'H', '0', 'Ml', 'B', '2', 'R', '4'],
#  ['Mu', 'H', '0', 'Ml', 'B', '2', 'R', '5'],
#  ['Mu', 'H', '0', 'Ml', 'B', '2', 'R', '6'],
# ...

# %%
df = pd.DataFrame(data=coded_exp1_trials, columns=columns)

# %%
df.to_csv('first_experiment_trials.csv')
